# %% [markdown]
# ⭐ Train an LSTM to solve the XOR problem: that is, given a sequence of bits, determine its parity. The LSTM should consume the sequence, one bit at a time, and then output the correct answer at the sequence’s end. Test the two approaches below:
#
# - Generate a dataset of random 100,000 binary strings of length 50. Train the LSTM; what performance do you get?
#
# - Generate a dataset of random 100,000 binary strings, where the length of each string is independently and randomly chosen between 1 and 50. Train the LSTM. Does it succeed? What explains the difference?

# %%
# import dependencies

import torch
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline  

from utils.data import generate_data, generate_rand_data
from network.network import Network

# %%
# generate data and initialize model
bit_strings, pairities = generate_data(1_000, 5)
model = Network(in_dim=1, out_dim=1, hid_dim=1, num_lay=1, lr=1e-3)
print(pairities.shape)
# Out:
# (1000, 1)

# %%
# train network
model.optimize(bit_strings, pairities, 100, 10)
# Out:
# torch.Size([50, 1000, 1])
# torch.Size([1000, 1])
# Training Network: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.93s/it]

# %%
# plot loss
plt.plot(model.historical_loss, label="Loss")
plt.plot(model.historical_accuracy, label="Accuracy")
plt.legend()
plt.show()
